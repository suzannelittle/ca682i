# %% [markdown]
# <a href="https://colab.research.google.com/github/suzannelittle/ca682i/blob/master/notebooks/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook contains some content from:
#
# <!--BOOK_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/figures/PDSH-cover-small.png?raw=1">
#
# *This notebook contains an excerpt from the [Python Data Science Handbook](http://shop.oreilly.com/product/0636920034919.do) by Jake VanderPlas; the content is available [on GitHub](https://github.com/jakevdp/PythonDataScienceHandbook).*
#
# *The text is released under the [CC-BY-NC-ND license](https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode), and code is released under the [MIT license](https://opensource.org/licenses/MIT). If you find this content useful, please consider supporting the work by [buying the book](http://shop.oreilly.com/product/0636920034919.do)!*

# %% [markdown]
# # Data Visualisation with Seaborn

# %% [markdown]
# Seaborn is a Python visualisation library based on matplotlib which provides the user with a high-level interface for creating attractive and informative statistical graphics. One of the biggest ways in which it improves <i>matplotlib</i> is that it provides a means of making graphs look much more aesthetically pleasing via simple functions.
#
# Let's start with the typical imports. Note the use of `plt.style.use('classic')` which tells matplotlib to use its classic formatting and colours.

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd

# %% [markdown]
# ## In-Built Themes:

# %% [markdown]
# When creating plots, it is desirable for them to be drawn in a manner that is aesthetically pleasing. Visualisations often attempt to convey quantitative insights to the reader, therefore it is important for them to be eye-catching and easy to comprehend.
#
# While <i>matplotlib</i> is highly customisable when it comes to how data is visually represented, a decent knowledge of the library is required to know exactly what tweaks to make in order to create an attractive figure. The <i>seaborn</i> library tackles this problem by offering a high-level interface for controlling the appearance of <i>matplotlib</i> figures as well as a number of customised themes.
#
# Below we can see the default appearance of a simple <i>matplotlib</i> graph:

# %%
plt.plot([0,1,2,3,4,5,6,7,8], [0,1,2,3,4,4,3,2,1], color='r')
plt.plot([0,1,2,3,4,5,6,7,8], [0,4,3,2,1,1,2,3,4], color='b')
plt.plot([0,1,2,3,4,5,6,7,8], [0,2,2,1,3,2,2,1,0], color='g')
plt.axis([0,8,0,5])

plt.show()

# %% [markdown]
# Let's see how the appearance of the above graph will change when we use <i>seaborn</i>. First, we must import the <i>seaborn</i> package:

# %%
import seaborn as sns
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Now, let's create the same graph again:

# %%
plt.plot([0,1,2,3,4,5,6,7,8], [0,1,2,3,4,4,3,2,1], color='r')
plt.plot([0,1,2,3,4,5,6,7,8], [0,4,3,2,1,1,2,3,4], color='b')
plt.plot([0,1,2,3,4,5,6,7,8], [0,2,2,1,3,2,2,1,0], color='g')
plt.axis([0,8,0,5])

plt.show()

# %% [markdown]
# The <i>seaborn</i> graph is noticeably more aesthetically pleasing with muted colours and better default structure with the grid lines against a gray background.

# %% [markdown]
# # Manipluating aesthetics
#
# <i>Seaborn</i> offers a pair of functions for manipulating the aesthetic style of the plot:
#
# - <i>set_style()</i>
# - <i>axes_style()</i>
#
# As well as this, it offers a pair of functions which relate to scaling different parts of the figure so that it can be easily incorporated into different contexts:
#
# - <i>plotting_context()</i>
# - <i>set_context()</i>
#
# For the above two pairs, the first function returns a dictionary of parameters while the second sets the matplotlib defaults.

# %% [markdown]
# ## set_style()
#
# <i>Seaborn</i> has five preset themes which can be passed in as parameters in the <i>set_style()</i> function: darkgrid (default), whitegrid, dark, white and ticks. Once you execute `sns.set_style('darkgrid')` then this style becomes the default one used for graphs generated. You can reset all styles to default by running `sns.reset_defaults()`.
#
# <img align="left" height="50" style="padding-right:10px;" src="https://raw.githubusercontent.com/suzannelittle/ca682i/master/resources/figures/try.png"/> Try changing the style to see the differences in the following simple line graph.

# %%
sns.set_style("whitegrid") 

plt.plot([1,2,3,4], [1,7,3,5])
plt.show()

# %% [markdown]
# Since both <i>white</i> and <i>ticks</i> themes have plain white backgrounds (and so generally blend in with the colour of the page they are being displayed on), these themes can often look better with the top and right axes' spines removed. This is an example of something that is impossible to do using <i>matplotlib</i> parameters but which one can easily do using seaborn's <i>despine()</i> function:

# %%
sns.set_style("ticks")
plt.plot([1,2,3,4],[1,2,3,4], linewidth=4)
plt.plot([1,2,3,4],[3.5,2.5,1.5,3], linewidth=4, color='r')

# Now remove top and right axes' spines
sns.despine()

plt.show()

# %% [markdown]
# ## axes_style()
#
# The other <i>seaborn</i> function mentioned above which relates to the plot's aesthetics is <i>axes_style()</i>. This function returns a dictionary of parameters that describe all of the specific style settings for a given theme.
#
# If the function is called with no parameters, it returns the stylistic details of the current theme; alternatively, you can pass in as a parameter the name of a specific theme:

# %%
sns.axes_style("darkgrid")
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': 'white',
#  'axes.facecolor': '#EAEAF2',
#  'axes.grid': True,
#  'axes.labelcolor': '.15',
#  'axes.spines.bottom': True,
#  'axes.spines.left': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True,
#  'figure.facecolor': 'white',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'image.cmap': 'rocket',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'text.color': '.15',
#  'xtick.bottom': False,
#  'xtick.color': '.15',
#  'xtick.direction': 'out',
#  'xtick.top': False,
#  'ytick.color': '.15',
#  'ytick.direction': 'out',
#  'ytick.left': False,
#  'ytick.right': False}

# %% [markdown]
# You can override the default values for the parameters of these themes using the <i>set_style()</i> function. Two parameters are passed in: the name of the theme you want to edit and a dictionary of the parameter(s) you want to change along with the value(s) you want them to be changed to:

# %%
sns.set_style("darkgrid", {'axes.facecolor': 'orange', 'axes.labelcolor': 'grey'})

plt.plot([1,2,3,4],[1,2,3,1.5], color="blue")   # using color overrides the colour palette of the style.
plt.xlabel("x-axis", fontsize=18)
plt.ylabel("y-axis", fontsize=18)
plt.axis([1,4,1,4])

plt.show()

# %% [markdown]
# > <b>Note:</b> Oh my eyes! Thankfully changing the above parameters does not permanently change the darkgrid style values. The changes you specify only apply until you call set_style again. You can see this by looking at the parameters for darkgrid by calling the <i>axes_style()</i> function for the theme and noting that its default parameters have not been changed.

# %%
sns.axes_style("darkgrid")
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': 'white',
#  'axes.facecolor': '#EAEAF2',
#  'axes.grid': True,
#  'axes.labelcolor': '.15',
#  'axes.spines.bottom': True,
#  'axes.spines.left': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True,
#  'figure.facecolor': 'white',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'image.cmap': 'rocket',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'text.color': '.15',
#  'xtick.bottom': False,
#  'xtick.color': '.15',
#  'xtick.direction': 'out',
#  'xtick.top': False,
#  'ytick.color': '.15',
#  'ytick.direction': 'out',
#  'ytick.left': False,
#  'ytick.right': False}

# %%
sns.set_style("darkgrid")

plt.plot([1,2,3,4],[1,2,3,1.5])
plt.xlabel("x-axis", fontsize=18)
plt.ylabel("y-axis", fontsize=18)
plt.axis([1,4,1,4])

plt.show()

# %% [markdown]
# ## Changing the plot context
#
# As mentioned earlier, <i>seaborn</i> also offers two functions which relate to the context of the plot. They are similar to the style functions in the sense that one is used for setting and the other is used for retrieval of details.
#
# The function for setting a different context for the plot is <i>set_context()</i>, the purpose of which is to change the size of the plot depending on the context in which you intend to use it. There are four preset contexts which can be passed in as parameters in this function, namely <i>paper, notebook, talk,</i> and <i>poster</i>.
#
# The default context in all plots so far has been <i>notebook</i>. Let's take a quick look at how the others look:
#
# - <i>Paper:</i>

# %%
sns.reset_defaults() #Sets style and context to default
sns.set_context("paper")

plt.plot([0,1,2,3,4],[1,3,6,3,2], 'b--', [0,1,2,3,4],[3,4,5,4,1],'r-')
plt.axis([0,4,0,7])
plt.show()

# %% [markdown]
# - <i>Talk:</i>

# %%
sns.set_context("talk")

plt.plot([0,1,2,3,4],[1,3,6,3,2], 'b--', [0,1,2,3,4],[3,4,5,4,1],'r-')
plt.axis([0,4,0,7])
plt.show()

# %% [markdown]
# - <i>Poster:</i>

# %%
sns.set_context("poster")

plt.plot([0,1,2,3,4],[1,3,6,3,2], 'b--', [0,1,2,3,4],[3,4,5,4,1],'r-')
plt.axis([0,4,0,7])
plt.show()

# %% [markdown]
# To reset both the aesthetic and context parameters to their default values, use seaborn's <i>reset_defaults()</i> function.
#
# You can also call `sns.set()` which with no parameters will run
# `seaborn.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)`. This allows you to set multiple aesthetic parameters in one step.

# %%
sns.reset_defaults()

# %% [markdown]
# ## Color Palettes:

# %% [markdown]
# Color is an integral aspect of visualisations as it has the power to convey <i>patterns</i> in the data that it is representing.
#
# Seaborn provides many [built-in palettes](https://seaborn.pydata.org/tutorial/color_palettes.html) of colours that we can use for visualisation.
#
# One of the key functions in seaborn is `color_palette()` that accepts the following as arguments:
#
# - The name of any seaborn palette
# - The name of any matplotlib color map
# - A list of colors specified in any valid matplotlib format, namely RGB tuples, hex color codes, or HTML color names
#
# Alternatively, you can call the function with no arguments which will return the current default color cycle. The format of the return value for `color_palette()` is a list of RGB tuples.
#
# Another useful function is `set_palette()` which sets the default color cycle for all plots and takes the same arguments as `color_palette()`.
#
# The default color palette when you import seaborn is a set of six colors which are a more aesthetically pleasing version of the standard matplotlib color cycle. We can display them and any other color palettes using seaborn's `palplot()` function which plots the values in a color palette as a horizontal array

# %%
sns.palplot(sns.color_palette())

# %% [markdown]
# <img align="left" height="50" style="padding-right:10px;" src="https://raw.githubusercontent.com/suzannelittle/ca682i/master/resources/figures/try.png"/> Try out some of the other palette options by giving the palette name to the `color_palette()` function.

# %%
sns.palplot(sns.color_palette("muted"))

# %% [markdown]
# You can also pass in a second parameter in the <i>color_palette()</i> function which specifies the number of colors you want to be displayed from the palette. If you reach the maximum number of colors in that palette it will cycle.

# %%
sns.palplot(sns.color_palette("colorblind", 15))

# %% [markdown]
# As you can see, it cycles once it displays its ten colors once.
#
# Another parameter that <i>color_palette()</i> accepts is a list of colors. Perhaps you just want a specific set of colors to represent your data or you have corporate branding to imitate, in which case you can do so using lists:

# %%
colors = ['red','yellow','green','blue','orange','purple']
sns.palplot(sns.color_palette(colors))

# %% [markdown]
# ## Applying Style, Context, and Palettes to a Plot:

# %% [markdown]
# To show how you would apply all the ideas we have covered so far in a single plot, let's create a barchart as an example using the Seaborn `barplot()` function rather than just altering the style of a matplotlib plot.

# %%
#Make necessary imports
import seaborn as sns
import matplotlib.pyplot as plt

#Set plot style
sns.set_style("ticks")

#Set plot context
sns.set_context("talk")

#Create bar chart (which takes 'palette' as a parameter)
sns.barplot(x=[1,2,3,4], y=[4,7,2,9], palette="pastel")

#Define range of x and y axes
plt.axis([-1,4,0,10])

plt.title("An example bar chart in Seaborn")

#Display bar chart
plt.show()
